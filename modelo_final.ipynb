# %% [markdown]
# # Notebook 2 - Uso del modelo final
#
# - Miembro 1: COMPLETAR NOMBRE + NIA
# - Miembro 2: COMPLETAR NOMBRE + NIA
#
# Este cuaderno se usará al final para cargar `modelo_final.joblib`, generar las predicciones del conjunto de competición y guardar `predicciones.csv`.

# %%
# Este bloque se completará cuando esté entrenado el modelo final.
# model = joblib.load('modelo_final.joblib')
# X_comp = pd.read_pickle('bank_competition_13.pkl')
# pred = model.predict(X_comp)
# pd.DataFrame({'deposit': pred}).to_csv('predicciones.csv', index=False)
