# %% [markdown]
# # Notebook 2 - Uso del modelo final
#
# - Miembro 1: **COMPLETAR NOMBRE + NIA**
# - Miembro 2: **COMPLETAR NOMBRE + NIA**
#
# Estado actual (15/03): notebook preparado como plantilla. Se completará cuando el modelo final esté seleccionado tras HPO y evaluación outer.

# %%
# Pendiente para siguiente fase:
# 1) model = joblib.load('modelo_final.joblib')
# 2) X_comp = pd.read_pickle('bank_competition_13.pkl')
# 3) pred = model.predict(X_comp)
# 4) Guardar predicciones.csv
