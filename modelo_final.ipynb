# %% [markdown]
# # Notebook 2 - Uso del modelo final
#
# - Miembro 1: Jorge López ALonso + 100495876
# - Miembro 2: Álvaro Carrasco Fuentes + 100495918
#
# Este cuaderno carga `modelo_final.joblib`, genera las predicciones del conjunto de competición y guarda el archivo final `predicciones.csv`.

# %%
import joblib
import pandas as pd

model = joblib.load('modelo_final.joblib')
X_comp = pd.read_pickle('bank_competition_13.pkl')

pred = model.predict(X_comp)
pred_df = pd.DataFrame({'deposit': pred})
pred_df.to_csv('predicciones.csv', index=False)

print('Predicciones guardadas en predicciones.csv')
print(pred_df['deposit'].value_counts())
pred_df.head()
# Out:
# Predicciones guardadas en predicciones.csv
# deposit
# no     93
# yes    69
# Name: count, dtype: int64
#   deposit
# 0      no
# 1      no
# 2      no
# 3     yes
# 4     yes

# %%
# Sacamos los datos del primer cliente (índice 0)
cliente_prueba = X_comp.iloc[[0]]
display(cliente_prueba)

# Vemos qué predice el modelo para este cliente
prediccion_notebook = model.predict(cliente_prueba)[0]
print(f"Predicción en el Notebook: {prediccion_notebook}")
# Out:
#       age         job  marital education default  balance housing loan  \
# 5553   43  management  married  tertiary      no       78     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome
# 5553  cellular   21   nov        36         1    109         1    other
# Predicción en el Notebook: no
